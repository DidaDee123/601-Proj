# %% [markdown]
# ### 1. Import modules

# %% [markdown]
# ### 2. Define path and load clean data

# %% [markdown]
# ### 3. Separate X and Ys

# %% [markdown]
# ### 4. Initiate models

# %% [markdown]
# ### 5. Train models

# %% [markdown]
# ### 6. Extract feature importances

# %% [markdown]
# ### 7. Summary and results
